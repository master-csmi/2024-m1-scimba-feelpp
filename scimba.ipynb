# %% [markdown]
# ### lap2D_pinns

# %%
from pathlib import Path

import scimba.nets.training_tools as training_tools
import scimba.pinns.pinn_losses as pinn_losses
import scimba.pinns.pinn_x as pinn_x
import scimba.pinns.training_x as training_x
import scimba.sampling.sampling_parameters as sampling_parameters
import scimba.sampling.sampling_pde as sampling_pde
import scimba.sampling.uniform_sampling as uniform_sampling
import torch
from scimba.equations import domain, pdes


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"torch loaded; device is {device}")

torch.set_default_dtype(torch.double)
torch.set_default_device(device)

PI = 3.14159265358979323846
ELLIPSOID_A = 4 / 3
ELLIPSOID_B = 1 / ELLIPSOID_A


class PoissonDisk2D(pdes.AbstractPDEx):
    def __init__(self, space_domain, 
                 rhs='4*pi*sin(pi*(x*x + y*y)) - 4*pi*pi*(x*x + y*y)*cos(pi*(x*x + y*y))', 
                 diff='(1,0,0,1)', 
                 g='0',
                 u_exact = 'sin(pi*(x*x + y*y))'):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=1,
            parameter_domain=[[0.5, 1]],
        )

        self.rhs = rhs
        self.diff = diff
        self.g = g
        self.u_exact = u_exact 
        self.first_derivative = True
        self.second_derivative = True

    def make_data(self, n_data):
        pass

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        x1, x2 = x.get_coordinates()
        g_evaluated = eval(self.g, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        return u - g_evaluated

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")

        f = eval(self.rhs, {'x': x1, 'y': x2, 'pi': PI, 'sin': torch.sin, 'cos': torch.cos})
        diff = eval(self.diff, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        
        return alpha*(u_xx * diff[0] + u_yy * diff[3] + f )


    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)

        return alpha*eval(self.u_exact, {'x': x1, 'y': x2, 'pi': PI, 'sin': torch.sin, 'cos': torch.cos})


class Poisson_2D(pdes.AbstractPDEx):
    def __init__(self, space_domain,  
                 rhs='8*pi*pi*sin(2*pi*x)*sin(2*pi*y)', 
                 diff='(1,0,0,1)', 
                 g='0',
                 u_exact='sin(2 * pi * x) * sin(2 * pi * y)'):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=1,
            parameter_domain=[[0.50000, 0.500001]],           
        )
        self.rhs = rhs
        self.diff = diff
        self.g = g
        self.u_exact = u_exact
        self.first_derivative = True
        self.second_derivative = True

    def make_data(self, n_data):
        pass

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        # Évaluation de la condition aux limites g
        x1, x2 = x.get_coordinates()
        g_evaluated = eval(self.g, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        return u - g_evaluated

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")

        f = eval(self.rhs, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        diff = eval(self.diff, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
    
        return alpha*(u_xx * diff[0] + u_yy * diff[3] + f)  
    
    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        return alpha*eval(self.u_exact, {'x': x1, 'y': x2, 'pi': PI, 'sin': torch.sin, 'cos': torch.cos})
   
    """
    def post_processing(self, x, mu, w):
        x1, x2 = x.get_coordinates()
        return x1 * (1 - x1) * x2 * (1 - x2) * w
    """

class Poisson_2D_ellipse(pdes.AbstractPDEx):
    def __init__(self, space_domain):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=0,
            parameter_domain=[[0.99999, 1]],
        )

        self.first_derivative = True
        self.second_derivative = True

    def make_data(self, n_data):
        pass

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        return u

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")
        f = 1
        return u_xx + u_yy + f

    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        x1_0, x2_0 = self.space_domain.large_domain.center
        a, b = ELLIPSOID_A, ELLIPSOID_B
        rho = 0.5 / (1 / a**2 + 1 / b**2)
        return rho * (1 - ((x1 - x1_0) / a) ** 2 - ((x2 - x2_0) / b) ** 2)


def disk_to_ellipse(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    return torch.cat((x1 * ELLIPSOID_A, x2 * ELLIPSOID_B), axis=1)


def Jacobian_disk_to_ellipse(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    return ELLIPSOID_A, 0, 0, ELLIPSOID_B


def disk_to_potato(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    x = x1 - 0.5 * x2**2 + 0.3 * torch.sin(x2)
    y = x2 + 0.1 * x + 0.12 * torch.cos(x)
    return torch.cat((x, y), axis=1)


def Jacobian_disk_to_potato(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    raise ValueError("Jacobian_disk_to_potato is not implemented")
    return 0, 0, 0, 0


def Run_laplacian2D(pde, epoch =100, bc_loss_bool=False, w_bc=0, w_res=1.0):
    x_sampler = sampling_pde.XSampler(pde=pde)
    mu_sampler = sampling_parameters.MuSampler(
        sampler=uniform_sampling.UniformSampling, model=pde
    )
    sampler = sampling_pde.PdeXCartesianSampler(x_sampler, mu_sampler)

    file_name = "test.pth"
    #new_training = False
    new_training = True

    if new_training:
        (
            Path.cwd()
            / Path(training_x.TrainerPINNSpace.FOLDER_FOR_SAVED_NETWORKS)
            / file_name
        ).unlink(missing_ok=True)

    tlayers = [20, 20, 20, 20, 20]
    network = pinn_x.MLP_x(pde=pde, layer_sizes=tlayers, activation_type="sine")
    pinn = pinn_x.PINNx(network, pde)
    losses = pinn_losses.PinnLossesData(
        bc_loss_bool=bc_loss_bool, w_res=w_res, w_bc=w_bc
    )
    optimizers = training_tools.OptimizerData(learning_rate=1.2e-2, decay=0.99)
    trainer = training_x.TrainerPINNSpace(
        pde=pde,
        network=pinn,
        sampler=sampler,
        losses=losses,
        optimizers=optimizers,
        file_name=file_name,
        batch_size=5000,
    )

    if not bc_loss_bool:
        if new_training:
            trainer.train(epochs=epoch, n_collocation=5000, n_data=0)
    else:
        if new_training:
            trainer.train(
                epochs=epoch, n_collocation=5000, n_bc_collocation=1000, n_data=0
            )

    trainer.plot(20000, reference_solution=True)
    #trainer.plot_derivative_mu(n_visu=20000)
    return network, pde


if __name__ == "__main__":
    # Laplacien strong Bc on Square with nn
    xdomain = domain.SpaceDomain(2, domain.SquareDomain(2, [[0.0, 1.0], [0.0, 1.0]]))
    print(xdomain)

    u_exact = 'y*y*y * (1 - y) - 2 * y*y * ((y - 1) * x * (1 - x)) + 6 * y * (1 - y)'
    rhs='-2 * (-6 + x * (2 - 6 * y) + 3 * y - 8 * y*y + 2 * y*y*y + x*x * (-2 + 6 * y))'

    pde = Poisson_2D(xdomain, rhs=rhs, g='y*y*y * (1 - y) - 2 * y*y * ((y - 1) * x * (1 - x)) + 6 * y * (1 - y)', u_exact = u_exact)
    network, pde = Run_laplacian2D(pde)

    u_exact = 'x'
    pde = Poisson_2D(xdomain, rhs='-1.0-4*y*x+y*y', g='x', u_exact=u_exact)
    network, pde = Run_laplacian2D(pde)
    
    u_exact='sin(2 * pi * x) * sin(2 * pi * y)'       
    pde = Poisson_2D(xdomain,  rhs='8*pi*pi*sin(2*pi*x)*sin(2*pi*y)', g='0',  u_exact=u_exact)
    network, pde = Run_laplacian2D(pde)

    u_exact = 'x*x/(1+x) + y*y/(1+y)'
    pde = Poisson_2D(xdomain, rhs='4', diff='(1+x,0,0,1+y)', g='x*x/(1+x) + y*y/(1+y)', u_exact=u_exact)
    network, pde = Run_laplacian2D(pde)
    
    xdomain = domain.SpaceDomain(2, domain.DiskBasedDomain(2, center=[0.0, 0.0], radius=1.0))
    u_exact =  'sin(pi*(x*x + y*y))'
    rhs = '4*pi*sin(pi*(x*x + y*y)) - 4*pi*pi*(x*x + y*y)*cos(pi*(x*x + y*y))'

    pde_disk = PoissonDisk2D(xdomain,  rhs= rhs, g= '0', u_exact=u_exact)
    network, pde = Run_laplacian2D(pde_disk)
    

    # Extract solution function u
    u = network.forward
    # Generate example input data and get the solution from the network
    input_tensor = torch.randn(100, 2)  # Generate some example input data
    mu = torch.tensor([[0.5]]).repeat(input_tensor.size(0), 1)  # Expand and repeat mu to match the batch size
    solution_tensor = u(input_tensor, mu)   # Get the solution from the network

    # Convert the tensor to a NumPy array
    solution_array = solution_tensor.detach().numpy()
    print('solution = ', solution_array)
# Out:
# Using device: cpu
# torch loaded; device is cpu
# <scimba.equations.domain.SpaceDomain object at 0x7f21898a3970>
# >> load network /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# network was not loaded from file: training needed
# epoch     0: current loss = 4.86e+01
# epoch     0: best loss = 4.86e+01
# epoch     1: best loss = 4.85e+01
# epoch     2: best loss = 4.74e+01
# epoch     3: best loss = 4.64e+01
# epoch     4: best loss = 4.40e+01
# epoch     5: best loss = 3.94e+01
# epoch     6: best loss = 3.23e+01
# epoch     7: best loss = 2.35e+01
# epoch     8: best loss = 1.90e+01
# epoch    11: best loss = 1.65e+01
# epoch    12: best loss = 1.35e+01
# epoch    15: best loss = 1.30e+01
# epoch    16: best loss = 1.08e+01
# epoch    17: best loss = 1.03e+01
# epoch    18: best loss = 9.09e+00
# epoch    21: best loss = 6.90e+00
# epoch    22: best loss = 6.59e+00
# epoch    25: best loss = 6.50e+00
# epoch    26: best loss = 6.29e+00
# epoch    27: best loss = 5.10e+00
# epoch    28: best loss = 4.69e+00
# epoch    31: best loss = 4.59e+00
# epoch    32: best loss = 4.10e+00
# epoch    33: best loss = 3.84e+00
# epoch    36: best loss = 3.51e+00
# epoch    37: best loss = 3.51e+00
# epoch    38: best loss = 2.99e+00
# epoch    40: best loss = 2.97e+00
# epoch    41: best loss = 2.86e+00
# epoch    42: best loss = 2.70e+00
# epoch    43: best loss = 2.38e+00
# epoch    45: best loss = 2.35e+00
# epoch    46: best loss = 2.12e+00
# epoch    47: best loss = 2.10e+00
# epoch    48: best loss = 1.80e+00
# epoch    50: best loss = 1.74e+00
# epoch    51: best loss = 1.58e+00
# epoch    52: best loss = 1.46e+00
# epoch    53: best loss = 1.34e+00
# epoch    54: best loss = 1.25e+00
# epoch    55: best loss = 1.10e+00
# epoch    56: best loss = 1.09e+00
# epoch    57: best loss = 9.34e-01
# epoch    58: best loss = 8.45e-01
# epoch    59: best loss = 7.63e-01
# epoch    60: best loss = 6.88e-01
# epoch    61: best loss = 6.38e-01
# epoch    62: best loss = 5.32e-01
# epoch    63: best loss = 4.86e-01
# epoch    64: best loss = 4.69e-01
# epoch    65: best loss = 4.10e-01
# epoch    66: best loss = 3.85e-01
# epoch    67: best loss = 3.55e-01
# epoch    68: best loss = 3.46e-01
# epoch    71: best loss = 3.39e-01
# epoch    72: best loss = 3.26e-01
# epoch    74: best loss = 3.13e-01
# epoch    75: best loss = 3.04e-01
# epoch    76: best loss = 2.86e-01
# epoch    77: best loss = 2.77e-01
# epoch    78: best loss = 2.51e-01
# epoch    79: best loss = 2.47e-01
# epoch    80: best loss = 2.21e-01
# epoch    81: best loss = 2.05e-01
# epoch    82: best loss = 2.03e-01
# epoch    83: best loss = 1.89e-01
# epoch    84: best loss = 1.83e-01
# epoch    85: best loss = 1.81e-01
# epoch    86: best loss = 1.65e-01
# epoch    88: best loss = 1.64e-01
# epoch    89: best loss = 1.52e-01
# epoch    90: best loss = 1.44e-01
# epoch    92: best loss = 1.41e-01
# epoch    94: best loss = 1.32e-01
# epoch    95: best loss = 1.30e-01
# epoch    96: best loss = 1.30e-01
# epoch    97: best loss = 1.28e-01
# epoch    98: best loss = 1.26e-01
# epoch    99: best loss = 1.24e-01
# epoch    99: current loss = 1.24e-01
# load network: /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# jsbdbshd
# network loaded
# >> load network /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# network was not loaded from file: training needed
# epoch     0: current loss = 8.20e-01
# epoch     0: best loss = 8.20e-01
# epoch     1: best loss = 7.69e-01
# epoch     2: best loss = 6.53e-01
# epoch     3: best loss = 4.88e-01
# epoch     4: best loss = 2.67e-01
# epoch     6: best loss = 2.67e-01
# epoch     7: best loss = 2.08e-01
# epoch    13: best loss = 1.78e-01
# epoch    14: best loss = 1.38e-01
# epoch    17: best loss = 1.33e-01
# epoch    18: best loss = 1.05e-01
# epoch    22: best loss = 1.02e-01
# epoch    23: best loss = 8.52e-02
# epoch    27: best loss = 7.19e-02
# epoch    28: best loss = 6.12e-02
# epoch    32: best loss = 4.93e-02
# epoch    33: best loss = 3.95e-02
# epoch    36: best loss = 3.11e-02
# epoch    39: best loss = 2.52e-02
# epoch    42: best loss = 2.02e-02
# epoch    43: best loss = 1.92e-02
# epoch    45: best loss = 1.87e-02
# epoch    46: best loss = 1.61e-02
# epoch    49: best loss = 1.48e-02
# epoch    52: best loss = 1.38e-02
# epoch    55: best loss = 1.30e-02
# epoch    56: best loss = 1.23e-02
# epoch    59: best loss = 1.22e-02
# epoch    62: best loss = 1.10e-02
# epoch    66: best loss = 1.07e-02
# epoch    70: best loss = 1.05e-02
# epoch    72: best loss = 1.01e-02
# epoch    73: best loss = 9.96e-03
# epoch    76: best loss = 9.93e-03
# epoch    79: best loss = 9.34e-03
# epoch    80: best loss = 9.24e-03
# epoch    82: best loss = 8.99e-03
# epoch    85: best loss = 8.90e-03
# epoch    89: best loss = 8.30e-03
# epoch    95: best loss = 8.05e-03
# epoch    99: best loss = 7.96e-03
# epoch    99: current loss = 7.96e-03
# load network: /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# jsbdbshd
# network loaded
# >> load network /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# network was not loaded from file: training needed
# epoch     0: current loss = 3.96e+02
# epoch     0: best loss = 3.96e+02
# epoch     1: best loss = 3.88e+02
# epoch     2: best loss = 3.86e+02
# epoch     4: best loss = 3.83e+02
# epoch     7: best loss = 3.76e+02
# epoch     8: best loss = 3.60e+02
# epoch     9: best loss = 2.96e+02
# epoch    10: best loss = 2.34e+02
# epoch    22: best loss = 2.32e+02
# epoch    23: best loss = 2.20e+02
# epoch    28: best loss = 2.18e+02
# epoch    34: best loss = 2.14e+02
# epoch    35: best loss = 2.05e+02
# epoch    40: best loss = 2.04e+02
# epoch    44: best loss = 2.04e+02
# epoch    45: best loss = 1.97e+02
# epoch    49: best loss = 1.95e+02
# epoch    51: best loss = 1.89e+02
# epoch    54: best loss = 1.88e+02
# epoch    59: best loss = 1.88e+02
# epoch    61: best loss = 1.87e+02
# epoch    68: best loss = 1.82e+02
# epoch    72: best loss = 1.79e+02
# epoch    76: best loss = 1.76e+02
# epoch    81: best loss = 1.76e+02
# epoch    85: best loss = 1.72e+02
# epoch    93: best loss = 1.71e+02
# epoch    94: best loss = 1.69e+02
# epoch    95: best loss = 1.66e+02
# epoch    99: current loss = 1.70e+02
# load network: /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# jsbdbshd
# network loaded
# >> load network /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# network was not loaded from file: training needed
# epoch     0: current loss = 4.02e+00
# epoch     0: best loss = 4.02e+00
# epoch     1: best loss = 3.92e+00
# epoch     2: best loss = 3.77e+00
# epoch     3: best loss = 3.43e+00
# epoch     4: best loss = 2.83e+00
# epoch     5: best loss = 1.91e+00
# epoch     6: best loss = 7.98e-01
# epoch     9: best loss = 1.87e-01
# epoch    14: best loss = 1.44e-01
# epoch    15: best loss = 2.60e-02
# epoch    33: best loss = 2.14e-02
# epoch    36: best loss = 1.97e-02
# epoch    37: best loss = 9.71e-03
# epoch    38: best loss = 8.06e-03
# epoch    52: best loss = 7.81e-03
# epoch    56: best loss = 6.62e-03
# epoch    58: best loss = 6.35e-03
# epoch    60: best loss = 5.44e-03
# epoch    61: best loss = 5.10e-03
# epoch    62: best loss = 4.83e-03
# epoch    64: best loss = 4.69e-03
# epoch    65: best loss = 3.98e-03
# epoch    66: best loss = 3.97e-03
# epoch    69: best loss = 3.65e-03
# epoch    70: best loss = 3.49e-03
# epoch    73: best loss = 3.35e-03
# epoch    74: best loss = 3.03e-03
# epoch    78: best loss = 2.84e-03
# epoch    81: best loss = 2.72e-03
# epoch    82: best loss = 2.71e-03
# epoch    84: best loss = 2.70e-03
# epoch    87: best loss = 2.63e-03
# epoch    88: best loss = 2.55e-03
# epoch    91: best loss = 2.52e-03
# epoch    92: best loss = 2.45e-03
# epoch    93: best loss = 2.28e-03
# epoch    99: best loss = 2.21e-03
# epoch    99: current loss = 2.21e-03
# load network: /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# jsbdbshd
# network loaded
# >> load network /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# network was not loaded from file: training needed
# epoch     0: current loss = 2.69e+02
# epoch     0: best loss = 2.69e+02
# epoch     1: best loss = 2.68e+02
# epoch     3: best loss = 2.60e+02
# epoch     4: best loss = 2.58e+02
# epoch     6: best loss = 2.47e+02
# epoch     7: best loss = 2.32e+02
# epoch     8: best loss = 2.26e+02
# epoch     9: best loss = 2.06e+02
# epoch    10: best loss = 1.98e+02
# epoch    11: best loss = 1.84e+02
# epoch    12: best loss = 1.79e+02
# epoch    13: best loss = 1.70e+02
# epoch    14: best loss = 1.68e+02
# epoch    15: best loss = 1.45e+02
# epoch    16: best loss = 1.42e+02
# epoch    17: best loss = 1.32e+02
# epoch    18: best loss = 1.07e+02
# epoch    19: best loss = 1.01e+02
# epoch    20: best loss = 9.16e+01
# epoch    23: best loss = 8.89e+01
# epoch    24: best loss = 8.63e+01
# epoch    25: best loss = 7.65e+01
# epoch    26: best loss = 7.30e+01
# epoch    27: best loss = 6.47e+01
# epoch    28: best loss = 5.67e+01
# epoch    29: best loss = 4.60e+01
# epoch    30: best loss = 3.79e+01
# epoch    31: best loss = 2.50e+01
# epoch    32: best loss = 1.42e+01
# epoch    33: best loss = 8.88e+00
# epoch    46: best loss = 8.77e+00
# epoch    47: best loss = 6.01e+00
# epoch    48: best loss = 4.79e+00
# epoch    55: best loss = 4.47e+00
# epoch    56: best loss = 3.61e+00
# epoch    57: best loss = 3.28e+00
# epoch    62: best loss = 3.08e+00
# epoch    63: best loss = 2.51e+00
# epoch    64: best loss = 2.37e+00
# epoch    65: best loss = 2.22e+00
# epoch    66: best loss = 2.21e+00
# epoch    70: best loss = 2.00e+00
# epoch    71: best loss = 1.77e+00
# epoch    72: best loss = 1.61e+00
# epoch    77: best loss = 1.50e+00
# epoch    78: best loss = 1.37e+00
# epoch    79: best loss = 1.31e+00
# epoch    84: best loss = 1.18e+00
# epoch    85: best loss = 1.15e+00
# epoch    86: best loss = 1.08e+00
# epoch    87: best loss = 1.03e+00
# epoch    89: best loss = 1.02e+00
# epoch    91: best loss = 1.02e+00
# epoch    92: best loss = 8.58e-01
# epoch    95: best loss = 8.36e-01
# epoch    97: best loss = 8.21e-01
# epoch    98: best loss = 7.67e-01
# epoch    99: current loss = 8.23e-01
# load network: /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# jsbdbshd
# network loaded
# solution =  [[ 1.01016381]
#  [-5.57124209]
#  [ 2.8672163 ]
#  [ 2.67956115]
#  [-3.69791081]
#  [-0.5751348 ]
#  [ 2.73967775]
#  [ 0.558567  ]
#  [-3.84278173]
#  [-5.4452205 ]
#  [-3.02564106]
#  [ 1.56817423]
#  [ 0.06133163]
#  [-0.80369686]
#  [ 2.59870103]
#  [ 2.64889585]
#  [-2.80231811]
#  [-6.55955375]
#  [-6.89057815]
#  [-6.09120065]
#  [-0.25316289]
#  [ 0.82716695]
#  [-3.35367375]
#  [-6.57502818]
#  [-1.21579293]
#  [ 2.85226223]
#  [-6.39109412]
#  [ 0.06402154]
#  [ 0.07404764]
#  [-5.73962144]
#  [ 2.54140111]
#  [ 2.6888319 ]
#  [ 2.79974609]
#  [ 1.51751962]
#  [-6.79777286]
#  [ 1.22455209]
#  [-1.84402824]
#  [-5.43464037]
#  [ 0.15379622]
#  [ 1.6601892 ]
#  [-6.07217165]
#  [ 1.21344017]
#  [ 2.50332081]
#  [-7.15343954]
#  [ 2.49548879]
#  [-6.24407923]
#  [ 0.08547771]
#  [-1.21304831]
#  [ 2.84914761]
#  [ 2.57169929]
#  [-1.66681712]
#  [-5.83089285]
#  [ 2.7886295 ]
#  [-4.17753878]
#  [-1.91664329]
#  [-6.76163467]
#  [ 0.68392348]
#  [-2.39631521]
#  [ 2.80285973]
#  [ 2.3925413 ]
#  [-3.29721606]
#  [-6.64495067]
#  [ 0.41045204]
#  [ 2.80752596]
#  [ 2.50623692]
#  [ 2.67300229]
#  [-6.39094312]
#  [-6.90663211]
#  [ 2.75204918]
#  [-4.01652348]
#  [-6.76233172]
#  [-2.25501177]
#  [-4.79075902]
#  [ 1.8472291 ]
#  [-6.20385901]
#  [-3.26238753]
#  [ 2.28552848]
#  [ 2.7193472 ]
#  [-1.19837085]
#  [-6.89305119]
#  [-5.42606241]
#  [-0.91797602]
#  [-2.41158466]
#  [ 2.77600065]
#  [ 1.21882044]
#  [-7.04214254]
#  [-6.83947184]
#  [ 1.87910399]
#  [ 2.46494544]
#  [ 1.42317159]
#  [ 0.36222907]
#  [-6.06635552]
#  [-6.81097626]
#  [-6.92239911]
#  [-7.2394463 ]
#  [ 2.23059609]
#  [-5.26218249]
#  [-5.25210278]
#  [-5.83316367]
#  [-2.82676678]]

# %% [markdown]
# ### lap2D_pinns2

# %%
from pathlib import Path

import scimba.nets.training_tools as training_tools
import scimba.pinns.pinn_losses as pinn_losses
import scimba.pinns.pinn_x as pinn_x
import scimba.pinns.training_x as training_x
import scimba.sampling.sampling_parameters as sampling_parameters
import scimba.sampling.sampling_pde as sampling_pde
import scimba.sampling.uniform_sampling as uniform_sampling
import torch
from scimba.equations import domain, pdes

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"torch loaded; device is {device}")

torch.set_default_dtype(torch.double)
torch.set_default_device(device)

PI = 3.14159265358979323846
ELLIPSOID_A = 4 / 3
ELLIPSOID_B = 1 / ELLIPSOID_A


class PoissonDisk2D(pdes.AbstractPDEx):
    def __init__(self, space_domain, 
                 rhs='4*pi*sin(pi*(x*x + y*y)) - 4*pi*pi*(x*x + y*y)*cos(pi*(x*x + y*y))', 
                 diff='(1,0,0,1)', 
                 g='0',
                 u_exact = 'sin(pi*(x*x + y*y))'):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=1,
            parameter_domain=[[0.5, 1]],
        )

        self.rhs = rhs
        self.diff = diff
        self.g = g
        self.u_exact = u_exact 
        self.first_derivative = True
        self.second_derivative = True

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        x1, x2 = x.get_coordinates()
        g_evaluated = eval(self.g, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        return u - g_evaluated

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")

        f = eval(self.rhs, {'x': x1, 'y': x2, 'pi': PI, 'sin': torch.sin, 'cos': torch.cos})
        diff = eval(self.diff, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        
        return u_xx * diff[0] + u_yy * diff[3] + f  


    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        return eval(self.u_exact, {'x': x1, 'y': x2, 'pi': PI, 'sin': torch.sin, 'cos': torch.cos})


class Poisson_2D(pdes.AbstractPDEx):
    def __init__(self, space_domain,  
                 rhs='8*pi*pi*sin(2*pi*x)*sin(2*pi*y)', 
                 diff='(1,0,0,1)', 
                 g='0',
                 u_exact='sin(2 * pi * x) * sin(2 * pi * y)'):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=1,
            parameter_domain=[[0.50000, 0.500001]],           
        )
        self.rhs = rhs
        self.diff = diff
        self.g = g
        self.u_exact = u_exact
        self.first_derivative = True
        self.second_derivative = True

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        # Évaluation de la condition aux limites g
        x1, x2 = x.get_coordinates()
        g_evaluated = eval(self.g, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        return u - g_evaluated

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")

        f = eval(self.rhs, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
        diff = eval(self.diff, {'x': x1, 'y': x2, 'pi': PI, 'sin' : torch.sin, 'cos': torch.cos})
    
        return u_xx * diff[0] + u_yy * diff[3] + f  

    """
    def post_processing(self, x, mu, w):
        x1, x2 = x.get_coordinates()
        return x1 * (1 - x1) * x2 * (1 - x2) * w
    """
    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        return eval(self.u_exact, {'x': x1, 'y': x2, 'pi': PI, 'sin': torch.sin, 'cos': torch.cos})

class Poisson_2D_ellipse(pdes.AbstractPDEx):
    def __init__(self, space_domain):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=0,
            parameter_domain=[[0.99999, 1]],
        )

        self.first_derivative = True
        self.second_derivative = True

    def make_data(self, n_data):
        pass

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        return u

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")
        f = 1
        return u_xx + u_yy + f

    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        x1_0, x2_0 = self.space_domain.large_domain.center
        a, b = ELLIPSOID_A, ELLIPSOID_B
        rho = 0.5 / (1 / a**2 + 1 / b**2)
        return rho * (1 - ((x1 - x1_0) / a) ** 2 - ((x2 - x2_0) / b) ** 2)


def disk_to_ellipse(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    return torch.cat((x1 * ELLIPSOID_A, x2 * ELLIPSOID_B), axis=1)


def Jacobian_disk_to_ellipse(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    return ELLIPSOID_A, 0, 0, ELLIPSOID_B


def disk_to_potato(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    x = x1 - 0.5 * x2**2 + 0.3 * torch.sin(x2)
    y = x2 + 0.1 * x + 0.12 * torch.cos(x)
    return torch.cat((x, y), axis=1)


def Jacobian_disk_to_potato(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    raise ValueError("Jacobian_disk_to_potato is not implemented")
    return 0, 0, 0, 0


def Run_laplacian2D(pde, bc_loss_bool=False, w_bc=0, w_res=1.0):
    x_sampler = sampling_pde.XSampler(pde=pde)
    mu_sampler = sampling_parameters.MuSampler(
        sampler=uniform_sampling.UniformSampling, model=pde
    )
    sampler = sampling_pde.PdeXCartesianSampler(x_sampler, mu_sampler)

    file_name = "test.pth"
    #new_training = False
    new_training = True

    if new_training:
        (
            Path.cwd()
            / Path(training_x.TrainerPINNSpace.FOLDER_FOR_SAVED_NETWORKS)
            / file_name
        ).unlink(missing_ok=True)

    tlayers = [20, 20, 20, 20, 20]
    network = pinn_x.MLP_x(pde=pde, layer_sizes=tlayers, activation_type="sine")
    pinn = pinn_x.PINNx(network, pde)
    losses = pinn_losses.PinnLossesData(
        bc_loss_bool=bc_loss_bool, w_res=w_res, w_bc=w_bc
    )
    optimizers = training_tools.OptimizerData(learning_rate=1.2e-2, decay=0.99)
    trainer = training_x.TrainerPINNSpace(
        pde=pde,
        network=pinn,
        sampler=sampler,
        losses=losses,
        optimizers=optimizers,
        file_name=file_name,
        batch_size=5000,
    )

    if not bc_loss_bool:
        if new_training:
            trainer.train(epochs=600, n_collocation=5000, n_data=0)
    else:
        if new_training:
            trainer.train(
                epochs=600, n_collocation=5000, n_bc_collocation=1000, n_data=0
            )

    trainer.plot(20000, reference_solution=True)
    # trainer.plot_derivative_mu(n_visu=20000)
    return network, pde


if __name__ == "__main__":
    # Laplacien strong Bc on Square with nn
    xdomain = domain.SpaceDomain(2, domain.SquareDomain(2, [[0.0, 1.0], [0.0, 1.0]]))
    print(xdomain)

    
    u_exact = 'y*y*y * (1 - y) - 2 * y*y * ((y - 1) * x * (1 - x)) + 6 * y * (1 - y)'
    rhs='-2 * (-6 + x * (2 - 6 * y) + 3 * y - 8 * y*y + 2 * y*y*y + x*x * (-2 + 6 * y))'

    pde = Poisson_2D(xdomain, rhs=rhs, g='y*y*y * (1 - y) - 2 * y*y * ((y - 1) * x * (1 - x)) + 6 * y * (1 - y)', u_exact = u_exact)
    Run_laplacian2D(pde)

    u_exact='sin(2 * pi * x) * sin(2 * pi * y)'       
    pde = Poisson_2D(xdomain,  rhs='8*pi*pi*sin(2*pi*x)*sin(2*pi*y)', g='0',  u_exact=u_exact)
    Run_laplacian2D(pde)
    
    u_exact = 'x'
    pde = Poisson_2D(xdomain, rhs='-1.0-4*y*x+y*y', g='x', u_exact=u_exact)
    Run_laplacian2D(pde)

    u_exact = 'x*x/(1+x) + y*y/(1+y)'
    pde = Poisson_2D(xdomain, rhs='4', diff='(1+x,0,0,1+y)', g='x*x/(1+x) + y*y/(1+y)', u_exact=u_exact)
    Run_laplacian2D(pde)

    xdomain = domain.SpaceDomain(2, domain.DiskBasedDomain(2, center=[0.0, 0.0], radius=1.0))
    u_exact =  'sin(pi*(x*x + y*y))'
    rhs = '4*pi*sin(pi*(x*x + y*y)) - 4*pi*pi*(x*x + y*y)*cos(pi*(x*x + y*y))'
    pde_disk = PoissonDisk2D(xdomain,  rhs= rhs, g= '0', u_exact=u_exact)
    Run_laplacian2D(pde_disk)
# Out:
# torch loaded; device is cpu
# <scimba.equations.domain.SpaceDomain object at 0x7f21898a3b80>
# >> load network /workspaces/2024-m1-scimba-feelpp-1/networks/test.pth
# network was not loaded from file: training needed
# epoch     0: current loss = 1.92e+02
# epoch     0: best loss = 1.92e+02
# epoch     3: best loss = 1.87e+02
# epoch     4: best loss = 1.79e+02
# epoch     5: best loss = 1.66e+02
# epoch     6: best loss = 1.46e+02
# epoch     7: best loss = 1.23e+02
# epoch     8: best loss = 9.31e+01
# epoch     9: best loss = 6.99e+01
# epoch    12: best loss = 6.69e+01
# epoch    13: best loss = 5.10e+01
# epoch    17: best loss = 4.94e+01
# epoch    18: best loss = 4.21e+01
# epoch    19: best loss = 3.31e+01
# epoch    20: best loss = 3.02e+01
# epoch    23: best loss = 2.49e+01
# epoch    24: best loss = 1.98e+01
# epoch    27: best loss = 1.98e+01
# epoch    28: best loss = 1.69e+01
# epoch    29: best loss = 1.32e+01
# epoch    30: best loss = 1.14e+01
# epoch    31: best loss = 1.07e+01
# epoch    35: best loss = 9.78e+00
# epoch    36: best loss = 8.89e+00
# epoch    37: best loss = 8.05e+00
# epoch    39: best loss = 7.49e+00
# epoch    40: best loss = 6.97e+00
# epoch    41: best loss = 6.26e+00
# epoch    43: best loss = 6.16e+00
# epoch    44: best loss = 6.07e+00
# epoch    45: best loss = 6.01e+00
# epoch    46: best loss = 5.43e+00
# epoch    47: best loss = 5.04e+00
# epoch    48: best loss = 4.44e+00
# epoch    49: best loss = 4.35e+00
# epoch    50: best loss = 4.08e+00
# epoch    51: best loss = 3.86e+00
# epoch    52: best loss = 3.55e+00
# epoch    53: best loss = 3.49e+00
# epoch    54: best loss = 3.41e+00
# epoch    55: best loss = 3.12e+00
# epoch    56: best loss = 2.81e+00
# epoch    57: best loss = 2.51e+00
# epoch    58: best loss = 2.15e+00
# epoch    59: best loss = 1.80e+00
# epoch    60: best loss = 1.54e+00
# epoch    61: best loss = 1.27e+00
# epoch    62: best loss = 1.13e+00
# epoch    63: best loss = 9.35e-01
# epoch    64: best loss = 6.89e-01
# epoch    65: best loss = 5.49e-01
# epoch    66: best loss = 4.69e-01
# epoch    71: best loss = 4.27e-01
# epoch    72: best loss = 3.76e-01
# epoch    73: best loss = 2.96e-01
# epoch    74: best loss = 2.48e-01
# epoch    75: best loss = 1.84e-01
# epoch    76: best loss = 1.64e-01
# epoch    85: best loss = 1.58e-01
# epoch    86: best loss = 1.45e-01
# epoch    87: best loss = 1.38e-01
# epoch    91: best loss = 1.36e-01
# epoch    92: best loss = 1.35e-01
# epoch    95: best loss = 1.25e-01
# epoch    96: best loss = 1.19e-01
# epoch   100: best loss = 1.15e-01
# epoch   101: best loss = 1.12e-01
# epoch   104: best loss = 1.12e-01
# epoch   106: best loss = 1.08e-01
# epoch   108: best loss = 1.05e-01
# epoch   110: best loss = 1.04e-01
# epoch   113: best loss = 1.04e-01
# epoch   115: best loss = 1.03e-01
# epoch   116: best loss = 9.92e-02
# epoch   118: best loss = 9.60e-02
# epoch   122: best loss = 9.07e-02
# epoch   129: best loss = 8.50e-02
# epoch   136: best loss = 8.33e-02
# epoch   139: best loss = 8.24e-02
# epoch   140: best loss = 8.19e-02
# epoch   143: best loss = 8.09e-02
# epoch   146: best loss = 8.07e-02
# epoch   148: best loss = 7.62e-02
# epoch   152: best loss = 7.51e-02
# epoch   156: best loss = 7.41e-02
# epoch   161: best loss = 7.10e-02
# epoch   171: best loss = 6.93e-02
# epoch   172: best loss = 6.89e-02
# epoch   175: best loss = 6.86e-02
# epoch   177: best loss = 6.75e-02
# epoch   181: best loss = 6.74e-02
# epoch   185: best loss = 6.67e-02
# epoch   186: best loss = 6.49e-02
# epoch   188: best loss = 6.29e-02
# epoch   191: best loss = 6.20e-02
# epoch   194: best loss = 5.87e-02
# epoch   204: best loss = 5.85e-02
# epoch   205: best loss = 5.81e-02
# epoch   206: best loss = 5.67e-02
# epoch   214: best loss = 5.42e-02
# epoch   216: best loss = 5.32e-02
# epoch   219: best loss = 5.18e-02
# epoch   222: best loss = 5.11e-02
# epoch   223: best loss = 5.07e-02
# epoch   225: best loss = 5.06e-02
# epoch   230: best loss = 4.97e-02
# epoch   236: best loss = 4.95e-02
# epoch   237: best loss = 4.94e-02
# epoch   238: best loss = 4.93e-02
# epoch   239: best loss = 4.65e-02
# epoch   250: best loss = 4.63e-02
# epoch   251: best loss = 4.43e-02
# epoch   254: best loss = 4.29e-02
# epoch   260: best loss = 4.24e-02
# epoch   261: best loss = 4.23e-02
# epoch   266: best loss = 4.16e-02
# epoch   267: best loss = 4.06e-02
# epoch   278: best loss = 3.98e-02
# epoch   279: best loss = 3.93e-02
# epoch   280: best loss = 3.74e-02
# epoch   293: best loss = 3.69e-02
# epoch   299: best loss = 3.59e-02
# epoch   301: best loss = 3.50e-02
# epoch   302: best loss = 3.47e-02
# epoch   308: best loss = 3.37e-02
# epoch   312: best loss = 3.32e-02
# epoch   316: best loss = 3.28e-02
# epoch   320: best loss = 3.22e-02
# epoch   322: best loss = 3.20e-02
# epoch   323: best loss = 3.19e-02
# epoch   326: best loss = 3.08e-02
# epoch   328: best loss = 3.06e-02
# epoch   330: best loss = 3.03e-02
# epoch   336: best loss = 2.92e-02
# epoch   346: best loss = 2.88e-02
# epoch   349: best loss = 2.79e-02
# epoch   365: best loss = 2.63e-02
# epoch   385: best loss = 2.57e-02
# epoch   387: best loss = 2.56e-02
# epoch   391: best loss = 2.52e-02
# epoch   397: best loss = 2.49e-02
# epoch   412: best loss = 2.39e-02
# epoch   446: best loss = 2.38e-02
# epoch   453: best loss = 2.28e-02
# epoch   471: best loss = 2.20e-02

# %% [markdown]
# ### laplacian2D_pinns

# %%
from pathlib import Path

import scimba.nets.training_tools as training_tools
import scimba.pinns.pinn_losses as pinn_losses
import scimba.pinns.pinn_x as pinn_x
import scimba.pinns.training_x as training_x
import scimba.sampling.sampling_parameters as sampling_parameters
import scimba.sampling.sampling_pde as sampling_pde
import scimba.sampling.uniform_sampling as uniform_sampling
import torch
from scimba.equations import domain, pdes

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"torch loaded; device is {device}")

torch.set_default_dtype(torch.double)
torch.set_default_device(device)

PI = 3.14159265358979323846
ELLIPSOID_A = 4 / 3
ELLIPSOID_B = 1 / ELLIPSOID_A


class PoissonDisk2D(pdes.AbstractPDEx):
    def __init__(self, space_domain):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=1,
            parameter_domain=[[0.5, 1]],
        )

        self.first_derivative = True
        self.second_derivative = True

    def make_data(self, n_data):
        pass

    def bc_residual(self, w, x, mu, **kwargs):
        return self.get_variables(w)

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")
        f = self.get_parameters(mu)
        return u_xx + u_yy + f

    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        x1_0, x2_0 = self.space_domain.large_domain.center
        f = self.get_parameters(mu)
        return 0.25 * f * (1 - (x1 - x1_0) ** 2 - (x2 - x2_0) ** 2)


class Poisson_2D(pdes.AbstractPDEx):
    def __init__(self, space_domain):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=1,
            parameter_domain=[[0.50000, 0.500001]],
        )

        self.first_derivative = True
        self.second_derivative = True

    def make_data(self, n_data):
        pass

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        return u

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")
        f = 8 * PI**2 * alpha * torch.sin(2 * PI * x1) * torch.sin(2 * PI * x2)
        return u_xx + u_yy + f

    def post_processing(self, x, mu, w):
        x1, x2 = x.get_coordinates()
        return x1 * (1 - x1) * x2 * (1 - x2) * w

    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        alpha = self.get_parameters(mu)
        return alpha * torch.sin(2 * PI * x1) * torch.sin(2 * PI * x2)


class Poisson_2D_ellipse(pdes.AbstractPDEx):
    def __init__(self, space_domain):
        super().__init__(
            nb_unknowns=1,
            space_domain=space_domain,
            nb_parameters=0,
            parameter_domain=[[0.99999, 1]],
        )

        self.first_derivative = True
        self.second_derivative = True

    def make_data(self, n_data):
        pass

    def bc_residual(self, w, x, mu, **kwargs):
        u = self.get_variables(w)
        return u

    def residual(self, w, x, mu, **kwargs):
        x1, x2 = x.get_coordinates()
        u_xx = self.get_variables(w, "w_xx")
        u_yy = self.get_variables(w, "w_yy")
        f = 1
        return u_xx + u_yy + f

    def reference_solution(self, x, mu):
        x1, x2 = x.get_coordinates()
        x1_0, x2_0 = self.space_domain.large_domain.center
        a, b = ELLIPSOID_A, ELLIPSOID_B
        rho = 0.5 / (1 / a**2 + 1 / b**2)
        return rho * (1 - ((x1 - x1_0) / a) ** 2 - ((x2 - x2_0) / b) ** 2)


def disk_to_ellipse(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    return torch.cat((x1 * ELLIPSOID_A, x2 * ELLIPSOID_B), axis=1)


def Jacobian_disk_to_ellipse(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    return ELLIPSOID_A, 0, 0, ELLIPSOID_B


def disk_to_potato(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    x = x1 - 0.5 * x2**2 + 0.3 * torch.sin(x2)
    y = x2 + 0.1 * x + 0.12 * torch.cos(x)
    return torch.cat((x, y), axis=1)


def Jacobian_disk_to_potato(x):
    x1, x2 = (x[:, i, None] for i in range(2))
    raise ValueError("Jacobian_disk_to_potato is not implemented")
    return 0, 0, 0, 0


def Run_laplacian2D(pde, bc_loss_bool=False, w_bc=0, w_res=1.0):
    x_sampler = sampling_pde.XSampler(pde=pde)
    mu_sampler = sampling_parameters.MuSampler(
        sampler=uniform_sampling.UniformSampling, model=pde
    )
    sampler = sampling_pde.PdeXCartesianSampler(x_sampler, mu_sampler)

    file_name = "test.pth"
    # new_training = False
    new_training = True

    if new_training:
        (
            Path.cwd()
            / Path(training_x.TrainerPINNSpace.FOLDER_FOR_SAVED_NETWORKS)
            / file_name
        ).unlink(missing_ok=True)

    tlayers = [20, 20, 20, 20, 20]
    network = pinn_x.MLP_x(pde=pde, layer_sizes=tlayers, activation_type="sine")
    pinn = pinn_x.PINNx(network, pde)
    losses = pinn_losses.PinnLossesData(
        bc_loss_bool=bc_loss_bool, w_res=w_res, w_bc=w_bc
    )
    optimizers = training_tools.OptimizerData(learning_rate=1.2e-2, decay=0.99)
    trainer = training_x.TrainerPINNSpace(
        pde=pde,
        network=pinn,
        sampler=sampler,
        losses=losses,
        optimizers=optimizers,
        file_name=file_name,
        batch_size=5000,
    )

    if not bc_loss_bool:
        if new_training:
            trainer.train(epochs=600, n_collocation=5000, n_data=0)
    else:
        if new_training:
            trainer.train(
                epochs=600, n_collocation=5000, n_bc_collocation=1000, n_data=0
            )

    trainer.plot(20000, reference_solution=True)
    # trainer.plot_derivative_mu(n_visu=20000)


if __name__ == "__main__":
    # Laplacien strong Bc on Square with nn
    xdomain = domain.SpaceDomain(2, domain.SquareDomain(2, [[0.0, 1.0], [0.0, 1.0]]))
    print(xdomain)
    pde = Poisson_2D(xdomain)

    Run_laplacian2D(pde)

    # Laplacian on circle with nn
    xdomain = domain.SpaceDomain(2, domain.DiskBasedDomain(2, [0.5, 0.5], 1.0))
    pde = PoissonDisk2D(xdomain)

    Run_laplacian2D(pde, bc_loss_bool=True, w_bc=10, w_res=0.1)
